# %%
import pandas as pd
import numpy as np

df = pd.read_csv('concept_dictionary_user.csv')
df.head()
# Out:
#       Label     Hindi      Eng    Marathi Telugu German Japanese
# 0      KA_1      KA_1    eat_1       KA_1   winu    NaN      NaN
# 1  ladakA_1  ladakA_1    boy_1   mulagA_1    NaN    NaN      NaN
# 2  kiwAba_1  kiwAba_1   book_1  puswaka_1    NaN    NaN      NaN
# 3    PaDa_1    PaDa_1   Read_1     Vaca_1    NaN    NaN      NaN
# 4    PaDa_2    PaDa_2  study_1     Sika_1    NaN    NaN      NaN

# %%
df = df[df['Eng'].notna()]

# %%
english = [word.split('_') for word in df['Eng'].word]
english
# Out:
# [['eat', '1'],
#  ['boy', '1'],
#  ['book', '1'],
#  ['Read', '1'],
#  ['study', '1'],
#  ['man', '1'],
#  ['come', '1'],
#  ['Know', '1'],
#  ['slow', '1'],
#  ['precious', '1'],
#  ['ice-cream', '1'],
#  ['today', '1'],
#  ['test', '1'],
#  ['lazy', '1'],
#  ['break', '1'],
#  ['rAma'],
#  ['begin', '1'],
#  ['need', '1'],
#  ['apply', '1'],
#  ['habit', '1'],
#  ['maid', '1'],
#  ['you', '1'],
#  ['age', '1'],
#  ['old', '2'],
#  ['brother', '1'],
#  ['run-away', '1'],
#  ['heavy', '1'],
#  ['also', '1'],
#  ['crowd', '1'],
#  ['hungry', '1'],
#  ['hunger', '1'],
#  ['welfare', '1'],
#  ['fill', '1'],
#  ['future', '1'],
#  ['send', '1'],
#  ['beggar', '1'],
#  ['food', '1'],
#  ['travel', '1'],
#  ['student', '1'],
#  ['scholarship', '1'],
#  ['miss', '1'],
#  ['discount', '2'],
#  ['six', '1'],
#  ['six', '2'],
#  ['leave', '1'],
#  ['drop', '2'],
#  ['small', '1'],
#  ['young', '2'],
#  ['holiday', '1'],
#  ['look', '1'],
#  ['seek', '2'],
#  ['find', '1'],
#  ['seek', '1'],
# ...

# %%
def translate(word):
    '''Returns Japanese translated string'''
    # here
    return trans

# %%
japanese = [translate(word[0])+'_'+word[1] for word in english if len(word) == 2 else translate(word[0])]
# Out:
# 'eat'

# %%
# Write to df and file
df['Japanese'] = japanese
df.to_excel('output.xlsx')
